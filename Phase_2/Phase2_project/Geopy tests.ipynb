# %%
import pandas as pd
import numpy as np

df = pd.read_csv("kc_house_data_train.csv")
# Out:
# time: 58.7 ms

# %%
from geopy.distance import geodesic

newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(geodesic(newport_ri, cleveland_oh).miles)
# Out:
# 538.3904453677204

# %%
from geopy.geocoders import Nominatim
from ratelimiter import RateLimiter

nominatim_service = Nominatim(user_agent='swelbeck12@gmail.com')

geolocator = (nominatim_service)

# %%
# collisions['geocodes'] = collisions['location_string'].apply(geolocator)

# %%
#  from geopy.geocoders import GoogleV3
#  geocoder = GoogleV3()
#  location_list = geocoder.reverse((latitude, longitude))
#  location = location_list[0]
#  address = location.address

# %%
from geopy.distance import great_circle
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(great_circle(newport_ri, cleveland_oh).miles)
# Out:
# 536.9979906964345

# %%
# %load_ext autotime
import pandas as pd
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import plotly_express as px
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.73 ms

# %%
locator = Nominatim(user_agent= 'myGeocoder')
coordinates = '53.480837, -2.244914'
location = locator.reverse(coordinates)
location.raw
# Out:
# {'place_id': 96393663,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 37139875,
#  'lat': '53.4809597',
#  'lon': '-2.2450668274629235',
#  'display_name': 'Eagle Insurance Buildings, 68, Cross Street, Chinatown, City Centre, Manchester, Greater Manchester, North West England, England, M2 4JG, United Kingdom',
#  'address': {'building': 'Eagle Insurance Buildings',
#   'house_number': '68',
#   'road': 'Cross Street',
#   'neighbourhood': 'Chinatown',
#   'suburb': 'City Centre',
#   'city': 'Manchester',
#   'county': 'Greater Manchester',
#   'state_district': 'North West England',
#   'state': 'England',
#   'postcode': 'M2 4JG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['53.480856', '53.4810634', '-2.2451761', '-2.2449576']}
# time: 640 ms

# %%
print(location.address['city'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-924d57e70a0a> in <module>
# ----> 1 print(location.address['city'])
#
# TypeError: string indices must be integers
# time: 80.3 ms

# %%
df.head()
# Out:
#    Unnamed: 0          id             date      price  bedrooms  bathrooms  \
# 0           0  2591820310  20141006T000000   365000.0         4       2.25
# 1           1  7974200820  20140821T000000   865000.0         5       3.00
# 2           2  7701450110  20140815T000000  1038000.0         4       2.50
# 3           3  9522300010  20150331T000000  1490000.0         3       3.50
# 4           4  9510861140  20140714T000000   711000.0         3       2.50
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         2070      8893     2.0           0  ...      8        2070
# 1         2900      6730     1.0           0  ...      8        1830
# 2         3770     10893     2.0           0  ...     11        3770
# 3         4560     14608     2.0           0  ...     12        4560
# 4         2550      5376     2.0           0  ...      9        2550
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
px.scatter_mapbox(df, lat='lat', lon='long', zoom=8)
# Out:
# <div>                            <div id="1567dd36-9f2e-4571-946a-c78963d54327" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1567dd36-9f2e-4571-946a-c78963d54327")) {                    Plotly.newPlot(                        "1567dd36-9f2e-4571-946a-c78963d54327",                        [{"hovertemplate": "lat=%{lat}<br>long=%{lon}<extra></extra>", "lat": [47.4388, 47.6784, 47.5646, 47.6995, 47.6647, 47.3947, 47.6596, 47.6599, 47.5344, 47.6341, 47.6052, 47.7733, 47.4908, 47.5419, 47.7093, 47.5194, 47.6255, 47.6398, 47.7133, 47.7434, 47.7074, 47.3065, 47.6145, 47.7328, 47.6179, 47.6432, 47.4483, 47.5533, 47.2089, 47.6382, 47.2069, 47.7263, 47.6379, 47.31100000000001, 47.7207, 47.5528, 47.5492, 47.389, 47.7279, 47.6332, 47.7657, 47.7466, 47.2602, 4
# ...

# %%
df["geom"] = df["lat"].map(str) + "," + df["long"].map(str)
df["geom"][0]
# Out:
# '47.4388,-122.162'
# time: 35.2 ms

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)
# Out:
# time: 2.37 ms

# %%
# tqdm.pandas()
# df["address"] = df["geom"].progress_apply(rgeocode)
# df.head()
# Out:
# 100%|██████████| 17290/17290 [3:31:23<00:00,  1.36it/s]
#    Unnamed: 0          id             date      price  bedrooms  bathrooms  \
# 0           0  2591820310  20141006T000000   365000.0         4       2.25
# 1           1  7974200820  20140821T000000   865000.0         5       3.00
# 2           2  7701450110  20140815T000000  1038000.0         4       2.50
# 3           3  9522300010  20150331T000000  1490000.0         3       3.50
# 4           4  9510861140  20140714T000000   711000.0         3       2.50
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  yr_built  \
# 0         2070      8893     2.0           0  ...              0      1986
# 1         2900      6730     1.0           0  ...           1070      1977
# 2         3770     10893     2.0           0  ...              0      1997
# 3         4560     14608     2.0           0  ...              0      1990
# 4         2550      5376     2.0           0  ...              0      2004
#
# ...

# %%
pd.set_option('display.max_colwidth',-1)
# Out:
# time: 12.5 ms
# <ipython-input-53-dc5dda32fe3d>:1: FutureWarning:
#
# Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
df.address[0]
# Out:
# Location(13408, Southeast 183rd Street, Forest Estates, Fairwood, King County, Washington, 98058, United States of America, (47.43878, -122.16184150000001, 0.0))
# time: 7.49 ms

# %%
df.to_csv('address_in_one_column.csv',index=False)
# Out:
# time: 707 ms

# %%
df2 = pd.concat([pd.DataFrame(df["address"].values.tolist()), df], axis = 1)
# Out:
# time: 849 ms

# %%
df2[0]
# Out:
# 0        13408, Southeast 183rd Street, Forest Estates, Fairwood, King County, Washington, 98058, United States of America
# 1        6825, 40th Avenue Northeast, Laurelhurst, Wedgwood, Seattle, King County, Washington, 98115, United States of America
# 2        15899, Southeast 45th Street, Eastgate, Bellevue, King County, Washington, 98006, United States of America
# 3        10933, 84th Place Northeast, Finn Hill, Kirkland, King County, Washington, 98034, United States of America
# 4        6534, 192nd Place Northeast, Woodbridge, Campton, Redmond, King County, Washington, 98052-6088, United States of America
#                                                                    ...
# 17285    17161, Southeast 26th Street, Sammamish Heights, Vasa Park, Bellevue, King County, Washington, 98008, United States of America
# 17286    5501, 37th Avenue Northeast, Inverness, Seattle, King County, Washington, 98105, United States of America
# ...
